# %% [markdown]
# ## Practice drill: rebuild day7's alignment loop, block by block
#
# Rules for this drill (matches your cheat sheet in day7):
# 1. We do **one block at a time**. I give you a skeleton with `TODO`s; you fill them in.
# 2. Run the cell, tell me what happens (works / errors / unsure), and we fix together before moving to the next block.
# 3. No peeking at day7's notebook until you've attempted the block yourself.
#
# **The 6 blocks we're rebuilding:**
# 1. Load model
# 2. Freeze most weights
# 3. Compute masked loss
# 4. Train loop
# 5. Eval before/after
# 6. Compare + stress-test
#
# Starting with **Block 1: Load model**.

# %%
# ============================================================
# BLOCK 1 of 6: Load model
# Goal: get a small model + tokenizer onto CPU, with a safe
# fallback if the preferred model can't be downloaded.
# ============================================================
import random
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

random.seed(7)
torch.manual_seed(7)
DEVICE = "cpu"
MODEL_NAME = "HuggingFaceTB/SmolLM2-135M-Instruct"
FALLBACK_MODEL = "sshleifer/tiny-gpt2"

def load_small_lm(model_name=MODEL_NAME):
    """Load the tokenizer + model this drill will generate from, score, and tune."""
    try:
        tokenizer = AutoTokenizer.from_pretrained(model_name)
        model = AutoModelForCausalLM.from_pretrained(model_name)
        loaded = model_name
    except Exception as exc:
        print(f"Could not load {model_name}: {exc}\nFalling back to {FALLBACK_MODEL}.")
        tokenizer = AutoTokenizer.from_pretrained(FALLBACK_MODEL)
        model = AutoModelForCausalLM.from_pretrained(FALLBACK_MODEL)
        loaded = FALLBACK_MODEL
    print(tokenizer)
    print("Loaded:", loaded)
    return tokenizer, model

# TODO: call load_small_lm() and unpack the result into `tokenizer` and `model`

# %%
load_small_lm()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 load_small_lm()
#
# Cell In[1], line 22, in load_small_lm(model_name)
#      18     try:
#      19         tokenizer = AutoTokenizer.from_pretrained(model_name)
#      20         model = AutoModelForCausalLM.from_pretrained(model_name)
#      21         loaded = model_name
# ---> 22     except Exception as exc:
#      23         print(f"Could not load {model_name}: {exc}\nFalling back to {FALLBACK_MODEL}.")
#      24         tokenizer = AutoTokenizer.from_pretrained(FALLBACK_MODEL)
#      25         model = AutoModelForCausalLM.from_pretrained(FALLBACK_MODEL)
#
# File c:\Users\ankitjai\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\auto\tokenization_auto.py:817, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
# ...

# %%
# create tensor
